# %% [markdown]
# # IPL dataset (ball by ball dataset)
# ball-by-ball dataset of Indian Premier League seasons

# %% [markdown]
# Kaggle data set link : https://www.kaggle.com/shrutisaxena/ipl-dataset-ball-by-ball-dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Mac Dataset path
import os
for dirname,_, filenames in os.walk('/Volumes/SARUN/ML - Date Sets/IPL Dataset'):
    print(len(filenames))
    for filname in filenames:
        print(os.path.join(dirname, filname))
# Out:
# 847
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/598068.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/598040.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/598054.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/1216499.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/829799.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/335990.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/335984.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/548329.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/548315.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/1082650.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/1082644.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/501259.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/1216512.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/501265.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/501271.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/1216506.csv
# /Volumes/SARUN/ML - Date Sets/IPL Dataset/981007.csv
# ...

# %%
import csv

with open('/Volumes/SARUN/ML - Date Sets/IPL Dataset/598068.csv', newline='', encoding='utf-8') as f:
    reader1 = csv.reader(f)
    row1 = next(reader1)
#reader1 = io.open('/Volumes/SARUN/ML - Date Sets/IPL Dataset/598068.csv', 'rb'), delimiter=',', encoding='utf8', quotechar='"')


with open('/Volumes/SARUN/ML - Date Sets/IPL Dataset/598040.csv', newline='', encoding='utf-8') as f:
    reader2 = csv.reader(f)
    row2 = next(reader2)
#reader2 = csv.reader(open('/Volumes/SARUN/ML - Date Sets/IPL Dataset/598040.csv', 'rb'), delimiter=',', encoding='utf8', quotechar='"')
#row2 = next(reader2)

if (row1[0] == row2[0]) and (row1[2:] == row2[2:]):
    print("eq")
else:
    print ("different")
# Out:
# eq

# %%
df1 = pd.read_csv('/Volumes/SARUN/ML - Date Sets/IPL Dataset/598068.csv')
df2 = pd.read_csv('/Volumes/SARUN/ML - Date Sets/IPL Dataset/598040.csv')

# %%
print(df1.head())
# Out:
#    match_id  season  start_date                  venue  innings  ball  \
# 0    598068    2013  2013-05-18  M Chinnaswamy Stadium        1   0.1
# 1    598068    2013  2013-05-18  M Chinnaswamy Stadium        1   0.2
# 2    598068    2013  2013-05-18  M Chinnaswamy Stadium        1   0.3
# 3    598068    2013  2013-05-18  M Chinnaswamy Stadium        1   0.4
# 4    598068    2013  2013-05-18  M Chinnaswamy Stadium        1   0.5
#
#                   batting_team         bowling_team   striker non_striker  \
# 0  Royal Challengers Bangalore  Chennai Super Kings   V Kohli    CH Gayle
# 1  Royal Challengers Bangalore  Chennai Super Kings   V Kohli    CH Gayle
# 2  Royal Challengers Bangalore  Chennai Super Kings   V Kohli    CH Gayle
# 3  Royal Challengers Bangalore  Chennai Super Kings   V Kohli    CH Gayle
# 4  Royal Challengers Bangalore  Chennai Super Kings  CH Gayle     V Kohli
#
#    ... extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# ...

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   match_id                100 non-null    int64
#  1   season                  100 non-null    int64
#  2   start_date              100 non-null    object
#  3   venue                   100 non-null    object
#  4   innings                 100 non-null    int64
#  5   ball                    100 non-null    float64
#  6   batting_team            100 non-null    object
#  7   bowling_team            100 non-null    object
#  8   striker                 100 non-null    object
#  9   non_striker             100 non-null    object
#  10  bowler                  100 non-null    object
#  11  runs_off_bat            100 non-null    int64
#  12  extras                  100 non-null    int64
#  13  wides                   4 non-null      float64
# ...
